# %%
import mlflow

print("Tracking URI:", mlflow.get_tracking_uri())
print("Experiment:", mlflow.get_experiment_by_name(mlflow.get_tracking_uri()))
# Out:
# Tracking URI: http://mlflow:5000
# Experiment: None

# %%
with mlflow.start_run(run_name="test_run"):
    mlflow.log_param("learning_rate", 0.01)
    mlflow.log_param("epochs", 10)
    mlflow.log_metric("accuracy", 0.95)
    mlflow.log_metric("loss", 0.12)
    print("Run ID:", mlflow.active_run().info.run_id)
# Out:
# Run ID: 6aea50ce34b14853814728b0751f0be6
# 🏃 View run test_run at: http://mlflow:5000/#/experiments/2/runs/6aea50ce34b14853814728b0751f0be6
# 🧪 View experiment at: http://mlflow:5000/#/experiments/2

# %%
last_run = mlflow.last_active_run()
experiment = mlflow.get_experiment(last_run.info.experiment_id)

print(f"Experiment: {experiment.name} (id={experiment.experiment_id})")

runs = mlflow.search_runs(experiment_ids=[last_run.info.experiment_id])
print(runs[['run_id', 'status', 'params.learning_rate', 'metrics.accuracy']].head())
# Out:
# Experiment: Examples (id=2)
#                              run_id    status params.learning_rate  \
# 0  6aea50ce34b14853814728b0751f0be6  FINISHED                 0.01
# 1  6bdd57c14f2f499e8ae7adc77c15c36f  FINISHED                 0.01
#
#    metrics.accuracy
# 0              0.95
# 1              0.95
